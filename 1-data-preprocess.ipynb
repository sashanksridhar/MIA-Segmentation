# %%
# !gdown --id 1989z-UY70MMNdDI9jKzlOOxv80MMvGaX
# Out:
# /home2/sashank.sridhar/miniconda3/envs/TripletLoss/lib/python3.9/site-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1989z-UY70MMNdDI9jKzlOOxv80MMvGaX
# To: /ssd_scratch/cvit/sashank.sridhar/ACDC.zip
# 100%|██████████████████████████████████████| 2.45G/2.45G [01:32<00:00, 26.5MB/s]

# %%
# !mkdir 'data'

# %%
# !unzip ACDC.zip -d data
# Out:
# Archive:  ACDC.zip
#  extracting: data/ACDC/database/testing/patient101/Info.cfg
#  extracting: data/ACDC/database/testing/patient101/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/testing/patient101/patient101_4d.nii.gz
#  extracting: data/ACDC/database/testing/patient101/patient101_frame01.nii.gz
#  extracting: data/ACDC/database/testing/patient101/patient101_frame01_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient101/patient101_frame14.nii.gz
#  extracting: data/ACDC/database/testing/patient101/patient101_frame14_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient102/Info.cfg
#  extracting: data/ACDC/database/testing/patient102/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/testing/patient102/patient102_4d.nii.gz
#  extracting: data/ACDC/database/testing/patient102/patient102_frame01.nii.gz
#  extracting: data/ACDC/database/testing/patient102/patient102_frame01_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient102/patient102_frame13.nii.gz
#  extracting: data/ACDC/database/testing/patient102/patient102_frame13_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient103/Info.cfg
#  extracting: data/ACDC/database/testing/patient103/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/testing/patient103/patient103_4d.nii.gz
#  extracting: data/ACDC/database/testing/patient103/patient103_frame01.nii.gz
#  extracting: data/ACDC/database/testing/patient103/patient103_frame01_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient103/patient103_frame11.nii.gz
#  extracting: data/ACDC/database/testing/patient103/patient103_frame11_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient104/Info.cfg
#  extracting: data/ACDC/database/testing/patient104/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/testing/patient104/patient104_4d.nii.gz
#  extracting: data/ACDC/database/testing/patient104/patient104_frame01.nii.gz
#  extracting: data/ACDC/database/testing/patient104/patient104_frame01_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient104/patient104_frame11.nii.gz
#  extracting: data/ACDC/database/testing/patient104/patient104_frame11_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient105/Info.cfg
#  extracting: data/ACDC/database/testing/patient105/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/testing/patient105/patient105_4d.nii.gz
#  extracting: data/ACDC/database/testing/patient105/patient105_frame01.nii.gz
#  extracting: data/ACDC/database/testing/patient105/patient105_frame01_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient105/patient105_frame10.nii.gz
#  extracting: data/ACDC/database/testing/patient105/patient105_frame10_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient106/Info.cfg
#  extracting: data/ACDC/database/testing/patient106/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/testing/patient106/patient106_4d.nii.gz
#  extracting: data/ACDC/database/testing/patient106/patient106_frame01.nii.gz
#  extracting: data/ACDC/database/testing/patient106/patient106_frame01_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient106/patient106_frame13.nii.gz
#  extracting: data/ACDC/database/testing/patient106/patient106_frame13_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient107/Info.cfg
#  extracting: data/ACDC/database/testing/patient107/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/testing/patient107/patient107_4d.nii.gz
#  extracting: data/ACDC/database/testing/patient107/patient107_frame01.nii.gz
#  extracting: data/ACDC/database/testing/patient107/patient107_frame01_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient107/patient107_frame10.nii.gz
#  extracting: data/ACDC/database/testing/patient107/patient107_frame10_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient108/Info.cfg
#  extracting: data/ACDC/database/testing/patient108/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/testing/patient108/patient108_4d.nii.gz
#  extracting: data/ACDC/database/testing/patient108/patient108_frame01.nii.gz
#  extracting: data/ACDC/database/testing/patient108/patient108_frame01_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient108/patient108_frame09.nii.gz
#  extracting: data/ACDC/database/testing/patient108/patient108_frame09_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient109/Info.cfg
#  extracting: data/ACDC/database/testing/patient109/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/testing/patient109/patient109_4d.nii.gz
#  extracting: data/ACDC/database/testing/patient109/patient109_frame01.nii.gz
#  extracting: data/ACDC/database/testing/patient109/patient109_frame01_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient109/patient109_frame10.nii.gz
#  extracting: data/ACDC/database/testing/patient109/patient109_frame10_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient110/Info.cfg
#  extracting: data/ACDC/database/testing/patient110/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/testing/patient110/patient110_4d.nii.gz
#  extracting: data/ACDC/database/testing/patient110/patient110_frame01.nii.gz
#  extracting: data/ACDC/database/testing/patient110/patient110_frame01_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient110/patient110_frame11.nii.gz
#  extracting: data/ACDC/database/testing/patient110/patient110_frame11_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient111/Info.cfg
#  extracting: data/ACDC/database/testing/patient111/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/testing/patient111/patient111_4d.nii.gz
#  extracting: data/ACDC/database/testing/patient111/patient111_frame01.nii.gz
#  extracting: data/ACDC/database/testing/patient111/patient111_frame01_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient111/patient111_frame07.nii.gz
#  extracting: data/ACDC/database/testing/patient111/patient111_frame07_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient112/Info.cfg
#  extracting: data/ACDC/database/testing/patient112/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/testing/patient112/patient112_4d.nii.gz
#  extracting: data/ACDC/database/testing/patient112/patient112_frame01.nii.gz
#  extracting: data/ACDC/database/testing/patient112/patient112_frame01_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient112/patient112_frame12.nii.gz
#  extracting: data/ACDC/database/testing/patient112/patient112_frame12_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient113/Info.cfg
#  extracting: data/ACDC/database/testing/patient113/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/testing/patient113/patient113_4d.nii.gz
#  extracting: data/ACDC/database/testing/patient113/patient113_frame01.nii.gz
#  extracting: data/ACDC/database/testing/patient113/patient113_frame01_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient113/patient113_frame08.nii.gz
#  extracting: data/ACDC/database/testing/patient113/patient113_frame08_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient114/Info.cfg
#  extracting: data/ACDC/database/testing/patient114/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/testing/patient114/patient114_4d.nii.gz
#  extracting: data/ACDC/database/testing/patient114/patient114_frame01.nii.gz
#  extracting: data/ACDC/database/testing/patient114/patient114_frame01_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient114/patient114_frame11.nii.gz
#  extracting: data/ACDC/database/testing/patient114/patient114_frame11_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient115/Info.cfg
#  extracting: data/ACDC/database/testing/patient115/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/testing/patient115/patient115_4d.nii.gz
#  extracting: data/ACDC/database/testing/patient115/patient115_frame01.nii.gz
#  extracting: data/ACDC/database/testing/patient115/patient115_frame01_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient115/patient115_frame13.nii.gz
#  extracting: data/ACDC/database/testing/patient115/patient115_frame13_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient116/Info.cfg
#  extracting: data/ACDC/database/testing/patient116/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/testing/patient116/patient116_4d.nii.gz
#  extracting: data/ACDC/database/testing/patient116/patient116_frame01.nii.gz
#  extracting: data/ACDC/database/testing/patient116/patient116_frame01_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient116/patient116_frame09.nii.gz
#  extracting: data/ACDC/database/testing/patient116/patient116_frame09_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient117/Info.cfg
#  extracting: data/ACDC/database/testing/patient117/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/testing/patient117/patient117_4d.nii.gz
#  extracting: data/ACDC/database/testing/patient117/patient117_frame01.nii.gz
#  extracting: data/ACDC/database/testing/patient117/patient117_frame01_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient117/patient117_frame13.nii.gz
#  extracting: data/ACDC/database/testing/patient117/patient117_frame13_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient118/Info.cfg
#  extracting: data/ACDC/database/testing/patient118/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/testing/patient118/patient118_4d.nii.gz
#  extracting: data/ACDC/database/testing/patient118/patient118_frame01.nii.gz
#  extracting: data/ACDC/database/testing/patient118/patient118_frame01_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient118/patient118_frame10.nii.gz
#  extracting: data/ACDC/database/testing/patient118/patient118_frame10_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient119/Info.cfg
#  extracting: data/ACDC/database/testing/patient119/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/testing/patient119/patient119_4d.nii.gz
#  extracting: data/ACDC/database/testing/patient119/patient119_frame01.nii.gz
#  extracting: data/ACDC/database/testing/patient119/patient119_frame01_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient119/patient119_frame09.nii.gz
#  extracting: data/ACDC/database/testing/patient119/patient119_frame09_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient120/Info.cfg
#  extracting: data/ACDC/database/testing/patient120/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/testing/patient120/patient120_4d.nii.gz
#  extracting: data/ACDC/database/testing/patient120/patient120_frame01.nii.gz
#  extracting: data/ACDC/database/testing/patient120/patient120_frame01_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient120/patient120_frame08.nii.gz
#  extracting: data/ACDC/database/testing/patient120/patient120_frame08_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient121/Info.cfg
#  extracting: data/ACDC/database/testing/patient121/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/testing/patient121/patient121_4d.nii.gz
#  extracting: data/ACDC/database/testing/patient121/patient121_frame01.nii.gz
#  extracting: data/ACDC/database/testing/patient121/patient121_frame01_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient121/patient121_frame10.nii.gz
#  extracting: data/ACDC/database/testing/patient121/patient121_frame10_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient122/Info.cfg
#  extracting: data/ACDC/database/testing/patient122/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/testing/patient122/patient122_4d.nii.gz
#  extracting: data/ACDC/database/testing/patient122/patient122_frame01.nii.gz
#  extracting: data/ACDC/database/testing/patient122/patient122_frame01_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient122/patient122_frame06.nii.gz
#  extracting: data/ACDC/database/testing/patient122/patient122_frame06_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient123/Info.cfg
#  extracting: data/ACDC/database/testing/patient123/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/testing/patient123/patient123_4d.nii.gz
#  extracting: data/ACDC/database/testing/patient123/patient123_frame01.nii.gz
#  extracting: data/ACDC/database/testing/patient123/patient123_frame01_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient123/patient123_frame11.nii.gz
#  extracting: data/ACDC/database/testing/patient123/patient123_frame11_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient124/Info.cfg
#  extracting: data/ACDC/database/testing/patient124/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/testing/patient124/patient124_4d.nii.gz
#  extracting: data/ACDC/database/testing/patient124/patient124_frame01.nii.gz
#  extracting: data/ACDC/database/testing/patient124/patient124_frame01_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient124/patient124_frame07.nii.gz
#  extracting: data/ACDC/database/testing/patient124/patient124_frame07_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient125/Info.cfg
#  extracting: data/ACDC/database/testing/patient125/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/testing/patient125/patient125_4d.nii.gz
#  extracting: data/ACDC/database/testing/patient125/patient125_frame01.nii.gz
#  extracting: data/ACDC/database/testing/patient125/patient125_frame01_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient125/patient125_frame07.nii.gz
#  extracting: data/ACDC/database/testing/patient125/patient125_frame07_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient126/Info.cfg
#  extracting: data/ACDC/database/testing/patient126/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/testing/patient126/patient126_4d.nii.gz
#  extracting: data/ACDC/database/testing/patient126/patient126_frame01.nii.gz
#  extracting: data/ACDC/database/testing/patient126/patient126_frame01_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient126/patient126_frame07.nii.gz
#  extracting: data/ACDC/database/testing/patient126/patient126_frame07_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient127/Info.cfg
#  extracting: data/ACDC/database/testing/patient127/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/testing/patient127/patient127_4d.nii.gz
#  extracting: data/ACDC/database/testing/patient127/patient127_frame01.nii.gz
#  extracting: data/ACDC/database/testing/patient127/patient127_frame01_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient127/patient127_frame07.nii.gz
#  extracting: data/ACDC/database/testing/patient127/patient127_frame07_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient128/Info.cfg
#  extracting: data/ACDC/database/testing/patient128/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/testing/patient128/patient128_4d.nii.gz
#  extracting: data/ACDC/database/testing/patient128/patient128_frame01.nii.gz
#  extracting: data/ACDC/database/testing/patient128/patient128_frame01_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient128/patient128_frame11.nii.gz
#  extracting: data/ACDC/database/testing/patient128/patient128_frame11_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient129/Info.cfg
#  extracting: data/ACDC/database/testing/patient129/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/testing/patient129/patient129_4d.nii.gz
#  extracting: data/ACDC/database/testing/patient129/patient129_frame01.nii.gz
#  extracting: data/ACDC/database/testing/patient129/patient129_frame01_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient129/patient129_frame08.nii.gz
#  extracting: data/ACDC/database/testing/patient129/patient129_frame08_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient130/Info.cfg
#  extracting: data/ACDC/database/testing/patient130/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/testing/patient130/patient130_4d.nii.gz
#  extracting: data/ACDC/database/testing/patient130/patient130_frame01.nii.gz
#  extracting: data/ACDC/database/testing/patient130/patient130_frame01_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient130/patient130_frame11.nii.gz
#  extracting: data/ACDC/database/testing/patient130/patient130_frame11_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient131/Info.cfg
#  extracting: data/ACDC/database/testing/patient131/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/testing/patient131/patient131_4d.nii.gz
#  extracting: data/ACDC/database/testing/patient131/patient131_frame01.nii.gz
#  extracting: data/ACDC/database/testing/patient131/patient131_frame01_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient131/patient131_frame09.nii.gz
#  extracting: data/ACDC/database/testing/patient131/patient131_frame09_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient132/Info.cfg
#  extracting: data/ACDC/database/testing/patient132/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/testing/patient132/patient132_4d.nii.gz
#  extracting: data/ACDC/database/testing/patient132/patient132_frame01.nii.gz
#  extracting: data/ACDC/database/testing/patient132/patient132_frame01_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient132/patient132_frame15.nii.gz
#  extracting: data/ACDC/database/testing/patient132/patient132_frame15_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient133/Info.cfg
#  extracting: data/ACDC/database/testing/patient133/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/testing/patient133/patient133_4d.nii.gz
#  extracting: data/ACDC/database/testing/patient133/patient133_frame01.nii.gz
#  extracting: data/ACDC/database/testing/patient133/patient133_frame01_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient133/patient133_frame10.nii.gz
#  extracting: data/ACDC/database/testing/patient133/patient133_frame10_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient134/Info.cfg
#  extracting: data/ACDC/database/testing/patient134/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/testing/patient134/patient134_4d.nii.gz
#  extracting: data/ACDC/database/testing/patient134/patient134_frame01.nii.gz
#  extracting: data/ACDC/database/testing/patient134/patient134_frame01_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient134/patient134_frame15.nii.gz
#  extracting: data/ACDC/database/testing/patient134/patient134_frame15_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient135/Info.cfg
#  extracting: data/ACDC/database/testing/patient135/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/testing/patient135/patient135_4d.nii.gz
#  extracting: data/ACDC/database/testing/patient135/patient135_frame01.nii.gz
#  extracting: data/ACDC/database/testing/patient135/patient135_frame01_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient135/patient135_frame10.nii.gz
#  extracting: data/ACDC/database/testing/patient135/patient135_frame10_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient136/Info.cfg
#  extracting: data/ACDC/database/testing/patient136/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/testing/patient136/patient136_4d.nii.gz
#  extracting: data/ACDC/database/testing/patient136/patient136_frame01.nii.gz
#  extracting: data/ACDC/database/testing/patient136/patient136_frame01_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient136/patient136_frame12.nii.gz
#  extracting: data/ACDC/database/testing/patient136/patient136_frame12_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient137/Info.cfg
#  extracting: data/ACDC/database/testing/patient137/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/testing/patient137/patient137_4d.nii.gz
#  extracting: data/ACDC/database/testing/patient137/patient137_frame01.nii.gz
#  extracting: data/ACDC/database/testing/patient137/patient137_frame01_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient137/patient137_frame11.nii.gz
#  extracting: data/ACDC/database/testing/patient137/patient137_frame11_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient138/Info.cfg
#  extracting: data/ACDC/database/testing/patient138/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/testing/patient138/patient138_4d.nii.gz
#  extracting: data/ACDC/database/testing/patient138/patient138_frame01.nii.gz
#  extracting: data/ACDC/database/testing/patient138/patient138_frame01_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient138/patient138_frame10.nii.gz
#  extracting: data/ACDC/database/testing/patient138/patient138_frame10_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient139/Info.cfg
#  extracting: data/ACDC/database/testing/patient139/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/testing/patient139/patient139_4d.nii.gz
#  extracting: data/ACDC/database/testing/patient139/patient139_frame01.nii.gz
#  extracting: data/ACDC/database/testing/patient139/patient139_frame01_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient139/patient139_frame08.nii.gz
#  extracting: data/ACDC/database/testing/patient139/patient139_frame08_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient140/Info.cfg
#  extracting: data/ACDC/database/testing/patient140/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/testing/patient140/patient140_4d.nii.gz
#  extracting: data/ACDC/database/testing/patient140/patient140_frame01.nii.gz
#  extracting: data/ACDC/database/testing/patient140/patient140_frame01_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient140/patient140_frame09.nii.gz
#  extracting: data/ACDC/database/testing/patient140/patient140_frame09_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient141/Info.cfg
#  extracting: data/ACDC/database/testing/patient141/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/testing/patient141/patient141_4d.nii.gz
#  extracting: data/ACDC/database/testing/patient141/patient141_frame01.nii.gz
#  extracting: data/ACDC/database/testing/patient141/patient141_frame01_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient141/patient141_frame11.nii.gz
#  extracting: data/ACDC/database/testing/patient141/patient141_frame11_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient142/Info.cfg
#  extracting: data/ACDC/database/testing/patient142/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/testing/patient142/patient142_4d.nii.gz
#  extracting: data/ACDC/database/testing/patient142/patient142_frame01.nii.gz
#  extracting: data/ACDC/database/testing/patient142/patient142_frame01_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient142/patient142_frame12.nii.gz
#  extracting: data/ACDC/database/testing/patient142/patient142_frame12_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient143/Info.cfg
#  extracting: data/ACDC/database/testing/patient143/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/testing/patient143/patient143_4d.nii.gz
#  extracting: data/ACDC/database/testing/patient143/patient143_frame01.nii.gz
#  extracting: data/ACDC/database/testing/patient143/patient143_frame01_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient143/patient143_frame12.nii.gz
#  extracting: data/ACDC/database/testing/patient143/patient143_frame12_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient144/Info.cfg
#  extracting: data/ACDC/database/testing/patient144/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/testing/patient144/patient144_4d.nii.gz
#  extracting: data/ACDC/database/testing/patient144/patient144_frame01.nii.gz
#  extracting: data/ACDC/database/testing/patient144/patient144_frame01_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient144/patient144_frame09.nii.gz
#  extracting: data/ACDC/database/testing/patient144/patient144_frame09_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient145/Info.cfg
#  extracting: data/ACDC/database/testing/patient145/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/testing/patient145/patient145_4d.nii.gz
#  extracting: data/ACDC/database/testing/patient145/patient145_frame01.nii.gz
#  extracting: data/ACDC/database/testing/patient145/patient145_frame01_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient145/patient145_frame13.nii.gz
#  extracting: data/ACDC/database/testing/patient145/patient145_frame13_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient146/Info.cfg
#  extracting: data/ACDC/database/testing/patient146/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/testing/patient146/patient146_4d.nii.gz
#  extracting: data/ACDC/database/testing/patient146/patient146_frame01.nii.gz
#  extracting: data/ACDC/database/testing/patient146/patient146_frame01_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient146/patient146_frame10.nii.gz
#  extracting: data/ACDC/database/testing/patient146/patient146_frame10_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient147/Info.cfg
#  extracting: data/ACDC/database/testing/patient147/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/testing/patient147/patient147_4d.nii.gz
#  extracting: data/ACDC/database/testing/patient147/patient147_frame01.nii.gz
#  extracting: data/ACDC/database/testing/patient147/patient147_frame01_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient147/patient147_frame09.nii.gz
#  extracting: data/ACDC/database/testing/patient147/patient147_frame09_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient148/Info.cfg
#  extracting: data/ACDC/database/testing/patient148/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/testing/patient148/patient148_4d.nii.gz
#  extracting: data/ACDC/database/testing/patient148/patient148_frame01.nii.gz
#  extracting: data/ACDC/database/testing/patient148/patient148_frame01_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient148/patient148_frame10.nii.gz
#  extracting: data/ACDC/database/testing/patient148/patient148_frame10_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient149/Info.cfg
#  extracting: data/ACDC/database/testing/patient149/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/testing/patient149/patient149_4d.nii.gz
#  extracting: data/ACDC/database/testing/patient149/patient149_frame01.nii.gz
#  extracting: data/ACDC/database/testing/patient149/patient149_frame01_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient149/patient149_frame12.nii.gz
#  extracting: data/ACDC/database/testing/patient149/patient149_frame12_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient150/Info.cfg
#  extracting: data/ACDC/database/testing/patient150/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/testing/patient150/patient150_4d.nii.gz
#  extracting: data/ACDC/database/testing/patient150/patient150_frame01.nii.gz
#  extracting: data/ACDC/database/testing/patient150/patient150_frame01_gt.nii.gz
#  extracting: data/ACDC/database/testing/patient150/patient150_frame12.nii.gz
#  extracting: data/ACDC/database/testing/patient150/patient150_frame12_gt.nii.gz
#  extracting: data/ACDC/database/testing/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/training/patient001/Info.cfg
#  extracting: data/ACDC/database/training/patient001/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/training/patient001/patient001_4d.nii.gz
#  extracting: data/ACDC/database/training/patient001/patient001_frame01.nii.gz
#  extracting: data/ACDC/database/training/patient001/patient001_frame01_gt.nii.gz
#  extracting: data/ACDC/database/training/patient001/patient001_frame12.nii.gz
#  extracting: data/ACDC/database/training/patient001/patient001_frame12_gt.nii.gz
#  extracting: data/ACDC/database/training/patient002/Info.cfg
#  extracting: data/ACDC/database/training/patient002/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/training/patient002/patient002_4d.nii.gz
#  extracting: data/ACDC/database/training/patient002/patient002_frame01.nii.gz
#  extracting: data/ACDC/database/training/patient002/patient002_frame01_gt.nii.gz
#  extracting: data/ACDC/database/training/patient002/patient002_frame12.nii.gz
#  extracting: data/ACDC/database/training/patient002/patient002_frame12_gt.nii.gz
#  extracting: data/ACDC/database/training/patient003/Info.cfg
#  extracting: data/ACDC/database/training/patient003/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/training/patient003/patient003_4d.nii.gz
#  extracting: data/ACDC/database/training/patient003/patient003_frame01.nii.gz
#  extracting: data/ACDC/database/training/patient003/patient003_frame01_gt.nii.gz
#  extracting: data/ACDC/database/training/patient003/patient003_frame15.nii.gz
#  extracting: data/ACDC/database/training/patient003/patient003_frame15_gt.nii.gz
#  extracting: data/ACDC/database/training/patient004/Info.cfg
#  extracting: data/ACDC/database/training/patient004/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/training/patient004/patient004_4d.nii.gz
#  extracting: data/ACDC/database/training/patient004/patient004_frame01.nii.gz
#  extracting: data/ACDC/database/training/patient004/patient004_frame01_gt.nii.gz
#  extracting: data/ACDC/database/training/patient004/patient004_frame15.nii.gz
#  extracting: data/ACDC/database/training/patient004/patient004_frame15_gt.nii.gz
#  extracting: data/ACDC/database/training/patient005/Info.cfg
#  extracting: data/ACDC/database/training/patient005/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/training/patient005/patient005_4d.nii.gz
#  extracting: data/ACDC/database/training/patient005/patient005_frame01.nii.gz
#  extracting: data/ACDC/database/training/patient005/patient005_frame01_gt.nii.gz
#  extracting: data/ACDC/database/training/patient005/patient005_frame13.nii.gz
#  extracting: data/ACDC/database/training/patient005/patient005_frame13_gt.nii.gz
#  extracting: data/ACDC/database/training/patient006/Info.cfg
#  extracting: data/ACDC/database/training/patient006/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/training/patient006/patient006_4d.nii.gz
#  extracting: data/ACDC/database/training/patient006/patient006_frame01.nii.gz
#  extracting: data/ACDC/database/training/patient006/patient006_frame01_gt.nii.gz
#  extracting: data/ACDC/database/training/patient006/patient006_frame16.nii.gz
#  extracting: data/ACDC/database/training/patient006/patient006_frame16_gt.nii.gz
#  extracting: data/ACDC/database/training/patient007/Info.cfg
#  extracting: data/ACDC/database/training/patient007/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/training/patient007/patient007_4d.nii.gz
#  extracting: data/ACDC/database/training/patient007/patient007_frame01.nii.gz
#  extracting: data/ACDC/database/training/patient007/patient007_frame01_gt.nii.gz
#  extracting: data/ACDC/database/training/patient007/patient007_frame07.nii.gz
#  extracting: data/ACDC/database/training/patient007/patient007_frame07_gt.nii.gz
#  extracting: data/ACDC/database/training/patient008/Info.cfg
#  extracting: data/ACDC/database/training/patient008/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/training/patient008/patient008_4d.nii.gz
#  extracting: data/ACDC/database/training/patient008/patient008_frame01.nii.gz
#  extracting: data/ACDC/database/training/patient008/patient008_frame01_gt.nii.gz
#  extracting: data/ACDC/database/training/patient008/patient008_frame13.nii.gz
#  extracting: data/ACDC/database/training/patient008/patient008_frame13_gt.nii.gz
#  extracting: data/ACDC/database/training/patient009/Info.cfg
#  extracting: data/ACDC/database/training/patient009/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/training/patient009/patient009_4d.nii.gz
#  extracting: data/ACDC/database/training/patient009/patient009_frame01.nii.gz
#  extracting: data/ACDC/database/training/patient009/patient009_frame01_gt.nii.gz
#  extracting: data/ACDC/database/training/patient009/patient009_frame13.nii.gz
#  extracting: data/ACDC/database/training/patient009/patient009_frame13_gt.nii.gz
#  extracting: data/ACDC/database/training/patient010/Info.cfg
#  extracting: data/ACDC/database/training/patient010/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/training/patient010/patient010_4d.nii.gz
#  extracting: data/ACDC/database/training/patient010/patient010_frame01.nii.gz
#  extracting: data/ACDC/database/training/patient010/patient010_frame01_gt.nii.gz
#  extracting: data/ACDC/database/training/patient010/patient010_frame13.nii.gz
#  extracting: data/ACDC/database/training/patient010/patient010_frame13_gt.nii.gz
#  extracting: data/ACDC/database/training/patient011/Info.cfg
#  extracting: data/ACDC/database/training/patient011/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/training/patient011/patient011_4d.nii.gz
#  extracting: data/ACDC/database/training/patient011/patient011_frame01.nii.gz
#  extracting: data/ACDC/database/training/patient011/patient011_frame01_gt.nii.gz
#  extracting: data/ACDC/database/training/patient011/patient011_frame08.nii.gz
#  extracting: data/ACDC/database/training/patient011/patient011_frame08_gt.nii.gz
#  extracting: data/ACDC/database/training/patient012/Info.cfg
#  extracting: data/ACDC/database/training/patient012/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/training/patient012/patient012_4d.nii.gz
#  extracting: data/ACDC/database/training/patient012/patient012_frame01.nii.gz
#  extracting: data/ACDC/database/training/patient012/patient012_frame01_gt.nii.gz
#  extracting: data/ACDC/database/training/patient012/patient012_frame13.nii.gz
#  extracting: data/ACDC/database/training/patient012/patient012_frame13_gt.nii.gz
#  extracting: data/ACDC/database/training/patient013/Info.cfg
#  extracting: data/ACDC/database/training/patient013/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/training/patient013/patient013_4d.nii.gz
#  extracting: data/ACDC/database/training/patient013/patient013_frame01.nii.gz
#  extracting: data/ACDC/database/training/patient013/patient013_frame01_gt.nii.gz
#  extracting: data/ACDC/database/training/patient013/patient013_frame14.nii.gz
#  extracting: data/ACDC/database/training/patient013/patient013_frame14_gt.nii.gz
#  extracting: data/ACDC/database/training/patient014/Info.cfg
#  extracting: data/ACDC/database/training/patient014/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/training/patient014/patient014_4d.nii.gz
#  extracting: data/ACDC/database/training/patient014/patient014_frame01.nii.gz
#  extracting: data/ACDC/database/training/patient014/patient014_frame01_gt.nii.gz
#  extracting: data/ACDC/database/training/patient014/patient014_frame13.nii.gz
#  extracting: data/ACDC/database/training/patient014/patient014_frame13_gt.nii.gz
#  extracting: data/ACDC/database/training/patient015/Info.cfg
#  extracting: data/ACDC/database/training/patient015/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/training/patient015/patient015_4d.nii.gz
#  extracting: data/ACDC/database/training/patient015/patient015_frame01.nii.gz
#  extracting: data/ACDC/database/training/patient015/patient015_frame01_gt.nii.gz
#  extracting: data/ACDC/database/training/patient015/patient015_frame10.nii.gz
#  extracting: data/ACDC/database/training/patient015/patient015_frame10_gt.nii.gz
#  extracting: data/ACDC/database/training/patient016/Info.cfg
#  extracting: data/ACDC/database/training/patient016/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/training/patient016/patient016_4d.nii.gz
#  extracting: data/ACDC/database/training/patient016/patient016_frame01.nii.gz
#  extracting: data/ACDC/database/training/patient016/patient016_frame01_gt.nii.gz
#  extracting: data/ACDC/database/training/patient016/patient016_frame12.nii.gz
#  extracting: data/ACDC/database/training/patient016/patient016_frame12_gt.nii.gz
#  extracting: data/ACDC/database/training/patient017/Info.cfg
#  extracting: data/ACDC/database/training/patient017/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/training/patient017/patient017_4d.nii.gz
#  extracting: data/ACDC/database/training/patient017/patient017_frame01.nii.gz
#  extracting: data/ACDC/database/training/patient017/patient017_frame01_gt.nii.gz
#  extracting: data/ACDC/database/training/patient017/patient017_frame09.nii.gz
#  extracting: data/ACDC/database/training/patient017/patient017_frame09_gt.nii.gz
#  extracting: data/ACDC/database/training/patient018/Info.cfg
#  extracting: data/ACDC/database/training/patient018/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/training/patient018/patient018_4d.nii.gz
#  extracting: data/ACDC/database/training/patient018/patient018_frame01.nii.gz
#  extracting: data/ACDC/database/training/patient018/patient018_frame01_gt.nii.gz
#  extracting: data/ACDC/database/training/patient018/patient018_frame10.nii.gz
#  extracting: data/ACDC/database/training/patient018/patient018_frame10_gt.nii.gz
#  extracting: data/ACDC/database/training/patient019/Info.cfg
#  extracting: data/ACDC/database/training/patient019/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/training/patient019/patient019_4d.nii.gz
#  extracting: data/ACDC/database/training/patient019/patient019_frame01.nii.gz
#  extracting: data/ACDC/database/training/patient019/patient019_frame01_gt.nii.gz
#  extracting: data/ACDC/database/training/patient019/patient019_frame11.nii.gz
#  extracting: data/ACDC/database/training/patient019/patient019_frame11_gt.nii.gz
#  extracting: data/ACDC/database/training/patient020/Info.cfg
#  extracting: data/ACDC/database/training/patient020/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/training/patient020/patient020_4d.nii.gz
#  extracting: data/ACDC/database/training/patient020/patient020_frame01.nii.gz
#  extracting: data/ACDC/database/training/patient020/patient020_frame01_gt.nii.gz
#  extracting: data/ACDC/database/training/patient020/patient020_frame11.nii.gz
#  extracting: data/ACDC/database/training/patient020/patient020_frame11_gt.nii.gz
#  extracting: data/ACDC/database/training/patient021/Info.cfg
#  extracting: data/ACDC/database/training/patient021/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/training/patient021/patient021_4d.nii.gz
#  extracting: data/ACDC/database/training/patient021/patient021_frame01.nii.gz
#  extracting: data/ACDC/database/training/patient021/patient021_frame01_gt.nii.gz
#  extracting: data/ACDC/database/training/patient021/patient021_frame13.nii.gz
#  extracting: data/ACDC/database/training/patient021/patient021_frame13_gt.nii.gz
#  extracting: data/ACDC/database/training/patient022/Info.cfg
#  extracting: data/ACDC/database/training/patient022/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/training/patient022/patient022_4d.nii.gz
#  extracting: data/ACDC/database/training/patient022/patient022_frame01.nii.gz
#  extracting: data/ACDC/database/training/patient022/patient022_frame01_gt.nii.gz
#  extracting: data/ACDC/database/training/patient022/patient022_frame11.nii.gz
#  extracting: data/ACDC/database/training/patient022/patient022_frame11_gt.nii.gz
#  extracting: data/ACDC/database/training/patient023/Info.cfg
#  extracting: data/ACDC/database/training/patient023/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/training/patient023/patient023_4d.nii.gz
#  extracting: data/ACDC/database/training/patient023/patient023_frame01.nii.gz
#  extracting: data/ACDC/database/training/patient023/patient023_frame01_gt.nii.gz
#  extracting: data/ACDC/database/training/patient023/patient023_frame09.nii.gz
#  extracting: data/ACDC/database/training/patient023/patient023_frame09_gt.nii.gz
#  extracting: data/ACDC/database/training/patient024/Info.cfg
#  extracting: data/ACDC/database/training/patient024/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/training/patient024/patient024_4d.nii.gz
#  extracting: data/ACDC/database/training/patient024/patient024_frame01.nii.gz
#  extracting: data/ACDC/database/training/patient024/patient024_frame01_gt.nii.gz
#  extracting: data/ACDC/database/training/patient024/patient024_frame09.nii.gz
#  extracting: data/ACDC/database/training/patient024/patient024_frame09_gt.nii.gz
#  extracting: data/ACDC/database/training/patient025/Info.cfg
#  extracting: data/ACDC/database/training/patient025/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/training/patient025/patient025_4d.nii.gz
#  extracting: data/ACDC/database/training/patient025/patient025_frame01.nii.gz
#  extracting: data/ACDC/database/training/patient025/patient025_frame01_gt.nii.gz
#  extracting: data/ACDC/database/training/patient025/patient025_frame09.nii.gz
#  extracting: data/ACDC/database/training/patient025/patient025_frame09_gt.nii.gz
#  extracting: data/ACDC/database/training/patient026/Info.cfg
#  extracting: data/ACDC/database/training/patient026/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/training/patient026/patient026_4d.nii.gz
#  extracting: data/ACDC/database/training/patient026/patient026_frame01.nii.gz
#  extracting: data/ACDC/database/training/patient026/patient026_frame01_gt.nii.gz
#  extracting: data/ACDC/database/training/patient026/patient026_frame12.nii.gz
#  extracting: data/ACDC/database/training/patient026/patient026_frame12_gt.nii.gz
#  extracting: data/ACDC/database/training/patient027/Info.cfg
#  extracting: data/ACDC/database/training/patient027/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/training/patient027/patient027_4d.nii.gz
#  extracting: data/ACDC/database/training/patient027/patient027_frame01.nii.gz
#  extracting: data/ACDC/database/training/patient027/patient027_frame01_gt.nii.gz
#  extracting: data/ACDC/database/training/patient027/patient027_frame11.nii.gz
#  extracting: data/ACDC/database/training/patient027/patient027_frame11_gt.nii.gz
#  extracting: data/ACDC/database/training/patient028/Info.cfg
#  extracting: data/ACDC/database/training/patient028/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/training/patient028/patient028_4d.nii.gz
#  extracting: data/ACDC/database/training/patient028/patient028_frame01.nii.gz
#  extracting: data/ACDC/database/training/patient028/patient028_frame01_gt.nii.gz
#  extracting: data/ACDC/database/training/patient028/patient028_frame09.nii.gz
#  extracting: data/ACDC/database/training/patient028/patient028_frame09_gt.nii.gz
#  extracting: data/ACDC/database/training/patient029/Info.cfg
#  extracting: data/ACDC/database/training/patient029/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/training/patient029/patient029_4d.nii.gz
#  extracting: data/ACDC/database/training/patient029/patient029_frame01.nii.gz
#  extracting: data/ACDC/database/training/patient029/patient029_frame01_gt.nii.gz
#  extracting: data/ACDC/database/training/patient029/patient029_frame12.nii.gz
#  extracting: data/ACDC/database/training/patient029/patient029_frame12_gt.nii.gz
#  extracting: data/ACDC/database/training/patient030/Info.cfg
#  extracting: data/ACDC/database/training/patient030/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/training/patient030/patient030_4d.nii.gz
#  extracting: data/ACDC/database/training/patient030/patient030_frame01.nii.gz
#  extracting: data/ACDC/database/training/patient030/patient030_frame01_gt.nii.gz
#  extracting: data/ACDC/database/training/patient030/patient030_frame12.nii.gz
#  extracting: data/ACDC/database/training/patient030/patient030_frame12_gt.nii.gz
#  extracting: data/ACDC/database/training/patient031/Info.cfg
#  extracting: data/ACDC/database/training/patient031/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/training/patient031/patient031_4d.nii.gz
#  extracting: data/ACDC/database/training/patient031/patient031_frame01.nii.gz
#  extracting: data/ACDC/database/training/patient031/patient031_frame01_gt.nii.gz
#  extracting: data/ACDC/database/training/patient031/patient031_frame10.nii.gz
#  extracting: data/ACDC/database/training/patient031/patient031_frame10_gt.nii.gz
#  extracting: data/ACDC/database/training/patient032/Info.cfg
#  extracting: data/ACDC/database/training/patient032/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/training/patient032/patient032_4d.nii.gz
#  extracting: data/ACDC/database/training/patient032/patient032_frame01.nii.gz
#  extracting: data/ACDC/database/training/patient032/patient032_frame01_gt.nii.gz
#  extracting: data/ACDC/database/training/patient032/patient032_frame12.nii.gz
#  extracting: data/ACDC/database/training/patient032/patient032_frame12_gt.nii.gz
#  extracting: data/ACDC/database/training/patient033/Info.cfg
#  extracting: data/ACDC/database/training/patient033/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/training/patient033/patient033_4d.nii.gz
#  extracting: data/ACDC/database/training/patient033/patient033_frame01.nii.gz
#  extracting: data/ACDC/database/training/patient033/patient033_frame01_gt.nii.gz
#  extracting: data/ACDC/database/training/patient033/patient033_frame14.nii.gz
#  extracting: data/ACDC/database/training/patient033/patient033_frame14_gt.nii.gz
#  extracting: data/ACDC/database/training/patient034/Info.cfg
#  extracting: data/ACDC/database/training/patient034/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/training/patient034/patient034_4d.nii.gz
#  extracting: data/ACDC/database/training/patient034/patient034_frame01.nii.gz
#  extracting: data/ACDC/database/training/patient034/patient034_frame01_gt.nii.gz
#  extracting: data/ACDC/database/training/patient034/patient034_frame16.nii.gz
#  extracting: data/ACDC/database/training/patient034/patient034_frame16_gt.nii.gz
#  extracting: data/ACDC/database/training/patient035/Info.cfg
#  extracting: data/ACDC/database/training/patient035/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/training/patient035/patient035_4d.nii.gz
#  extracting: data/ACDC/database/training/patient035/patient035_frame01.nii.gz
#  extracting: data/ACDC/database/training/patient035/patient035_frame01_gt.nii.gz
#  extracting: data/ACDC/database/training/patient035/patient035_frame11.nii.gz
#  extracting: data/ACDC/database/training/patient035/patient035_frame11_gt.nii.gz
#  extracting: data/ACDC/database/training/patient036/Info.cfg
#  extracting: data/ACDC/database/training/patient036/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/training/patient036/patient036_4d.nii.gz
#  extracting: data/ACDC/database/training/patient036/patient036_frame01.nii.gz
#  extracting: data/ACDC/database/training/patient036/patient036_frame01_gt.nii.gz
#  extracting: data/ACDC/database/training/patient036/patient036_frame12.nii.gz
#  extracting: data/ACDC/database/training/patient036/patient036_frame12_gt.nii.gz
#  extracting: data/ACDC/database/training/patient037/Info.cfg
#  extracting: data/ACDC/database/training/patient037/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/training/patient037/patient037_4d.nii.gz
#  extracting: data/ACDC/database/training/patient037/patient037_frame01.nii.gz
#  extracting: data/ACDC/database/training/patient037/patient037_frame01_gt.nii.gz
#  extracting: data/ACDC/database/training/patient037/patient037_frame12.nii.gz
#  extracting: data/ACDC/database/training/patient037/patient037_frame12_gt.nii.gz
#  extracting: data/ACDC/database/training/patient038/Info.cfg
#  extracting: data/ACDC/database/training/patient038/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/training/patient038/patient038_4d.nii.gz
#  extracting: data/ACDC/database/training/patient038/patient038_frame01.nii.gz
#  extracting: data/ACDC/database/training/patient038/patient038_frame01_gt.nii.gz
#  extracting: data/ACDC/database/training/patient038/patient038_frame11.nii.gz
#  extracting: data/ACDC/database/training/patient038/patient038_frame11_gt.nii.gz
#  extracting: data/ACDC/database/training/patient039/Info.cfg
#  extracting: data/ACDC/database/training/patient039/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/training/patient039/patient039_4d.nii.gz
#  extracting: data/ACDC/database/training/patient039/patient039_frame01.nii.gz
#  extracting: data/ACDC/database/training/patient039/patient039_frame01_gt.nii.gz
#  extracting: data/ACDC/database/training/patient039/patient039_frame10.nii.gz
#  extracting: data/ACDC/database/training/patient039/patient039_frame10_gt.nii.gz
#  extracting: data/ACDC/database/training/patient040/Info.cfg
#  extracting: data/ACDC/database/training/patient040/MANDATORY_CITATION.md
# ...
#  extracting: data/ACDC/database/training/patient071/patient071_frame09.nii.gz
#  extracting: data/ACDC/database/training/patient071/patient071_frame09_gt.nii.gz
#  extracting: data/ACDC/database/training/patient072/Info.cfg
#  extracting: data/ACDC/database/training/patient072/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/training/patient072/patient072_4d.nii.gz
#  extracting: data/ACDC/database/training/patient072/patient072_frame01.nii.gz
#  extracting: data/ACDC/database/training/patient072/patient072_frame01_gt.nii.gz
#  extracting: data/ACDC/database/training/patient072/patient072_frame11.nii.gz
#  extracting: data/ACDC/database/training/patient072/patient072_frame11_gt.nii.gz
#  extracting: data/ACDC/database/training/patient073/Info.cfg
#  extracting: data/ACDC/database/training/patient073/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/training/patient073/patient073_4d.nii.gz
#  extracting: data/ACDC/database/training/patient073/patient073_frame01.nii.gz
#  extracting: data/ACDC/database/training/patient073/patient073_frame01_gt.nii.gz
#  extracting: data/ACDC/database/training/patient073/patient073_frame10.nii.gz
#  extracting: data/ACDC/database/training/patient073/patient073_frame10_gt.nii.gz
#  extracting: data/ACDC/database/training/patient074/Info.cfg
#  extracting: data/ACDC/database/training/patient074/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/training/patient074/patient074_4d.nii.gz
#  extracting: data/ACDC/database/training/patient074/patient074_frame01.nii.gz
#  extracting: data/ACDC/database/training/patient074/patient074_frame01_gt.nii.gz
#  extracting: data/ACDC/database/training/patient074/patient074_frame12.nii.gz
#  extracting: data/ACDC/database/training/patient074/patient074_frame12_gt.nii.gz
#  extracting: data/ACDC/database/training/patient075/Info.cfg
#  extracting: data/ACDC/database/training/patient075/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/training/patient075/patient075_4d.nii.gz
#  extracting: data/ACDC/database/training/patient075/patient075_frame01.nii.gz
#  extracting: data/ACDC/database/training/patient075/patient075_frame01_gt.nii.gz
#  extracting: data/ACDC/database/training/patient075/patient075_frame06.nii.gz
#  extracting: data/ACDC/database/training/patient075/patient075_frame06_gt.nii.gz
#  extracting: data/ACDC/database/training/patient076/Info.cfg
#  extracting: data/ACDC/database/training/patient076/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/training/patient076/patient076_4d.nii.gz
#  extracting: data/ACDC/database/training/patient076/patient076_frame01.nii.gz
#  extracting: data/ACDC/database/training/patient076/patient076_frame01_gt.nii.gz
#  extracting: data/ACDC/database/training/patient076/patient076_frame12.nii.gz
#  extracting: data/ACDC/database/training/patient076/patient076_frame12_gt.nii.gz
#  extracting: data/ACDC/database/training/patient077/Info.cfg
#  extracting: data/ACDC/database/training/patient077/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/training/patient077/patient077_4d.nii.gz
#  extracting: data/ACDC/database/training/patient077/patient077_frame01.nii.gz
#  extracting: data/ACDC/database/training/patient077/patient077_frame01_gt.nii.gz
#  extracting: data/ACDC/database/training/patient077/patient077_frame09.nii.gz
#  extracting: data/ACDC/database/training/patient077/patient077_frame09_gt.nii.gz
#  extracting: data/ACDC/database/training/patient078/Info.cfg
#  extracting: data/ACDC/database/training/patient078/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/training/patient078/patient078_4d.nii.gz
#  extracting: data/ACDC/database/training/patient078/patient078_frame01.nii.gz
#  extracting: data/ACDC/database/training/patient078/patient078_frame01_gt.nii.gz
#  extracting: data/ACDC/database/training/patient078/patient078_frame09.nii.gz
#  extracting: data/ACDC/database/training/patient078/patient078_frame09_gt.nii.gz
#  extracting: data/ACDC/database/training/patient079/Info.cfg
#  extracting: data/ACDC/database/training/patient079/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/training/patient079/patient079_4d.nii.gz
#  extracting: data/ACDC/database/training/patient079/patient079_frame01.nii.gz
#  extracting: data/ACDC/database/training/patient079/patient079_frame01_gt.nii.gz
#  extracting: data/ACDC/database/training/patient079/patient079_frame11.nii.gz
#  extracting: data/ACDC/database/training/patient079/patient079_frame11_gt.nii.gz
#  extracting: data/ACDC/database/training/patient080/Info.cfg
#  extracting: data/ACDC/database/training/patient080/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/training/patient080/patient080_4d.nii.gz
#  extracting: data/ACDC/database/training/patient080/patient080_frame01.nii.gz
#  extracting: data/ACDC/database/training/patient080/patient080_frame01_gt.nii.gz
#  extracting: data/ACDC/database/training/patient080/patient080_frame10.nii.gz
#  extracting: data/ACDC/database/training/patient080/patient080_frame10_gt.nii.gz
#  extracting: data/ACDC/database/training/patient081/Info.cfg
#  extracting: data/ACDC/database/training/patient081/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/training/patient081/patient081_4d.nii.gz
#  extracting: data/ACDC/database/training/patient081/patient081_frame01.nii.gz
#  extracting: data/ACDC/database/training/patient081/patient081_frame01_gt.nii.gz
#  extracting: data/ACDC/database/training/patient081/patient081_frame07.nii.gz
#  extracting: data/ACDC/database/training/patient081/patient081_frame07_gt.nii.gz
#  extracting: data/ACDC/database/training/patient082/Info.cfg
#  extracting: data/ACDC/database/training/patient082/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/training/patient082/patient082_4d.nii.gz
#  extracting: data/ACDC/database/training/patient082/patient082_frame01.nii.gz
#  extracting: data/ACDC/database/training/patient082/patient082_frame01_gt.nii.gz
#  extracting: data/ACDC/database/training/patient082/patient082_frame07.nii.gz
#  extracting: data/ACDC/database/training/patient082/patient082_frame07_gt.nii.gz
#  extracting: data/ACDC/database/training/patient083/Info.cfg
#  extracting: data/ACDC/database/training/patient083/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/training/patient083/patient083_4d.nii.gz
#  extracting: data/ACDC/database/training/patient083/patient083_frame01.nii.gz
#  extracting: data/ACDC/database/training/patient083/patient083_frame01_gt.nii.gz
#  extracting: data/ACDC/database/training/patient083/patient083_frame08.nii.gz
#  extracting: data/ACDC/database/training/patient083/patient083_frame08_gt.nii.gz
#  extracting: data/ACDC/database/training/patient084/Info.cfg
#  extracting: data/ACDC/database/training/patient084/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/training/patient084/patient084_4d.nii.gz
#  extracting: data/ACDC/database/training/patient084/patient084_frame01.nii.gz
#  extracting: data/ACDC/database/training/patient084/patient084_frame01_gt.nii.gz
#  extracting: data/ACDC/database/training/patient084/patient084_frame10.nii.gz
#  extracting: data/ACDC/database/training/patient084/patient084_frame10_gt.nii.gz
#  extracting: data/ACDC/database/training/patient085/Info.cfg
#  extracting: data/ACDC/database/training/patient085/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/training/patient085/patient085_4d.nii.gz
#  extracting: data/ACDC/database/training/patient085/patient085_frame01.nii.gz
#  extracting: data/ACDC/database/training/patient085/patient085_frame01_gt.nii.gz
#  extracting: data/ACDC/database/training/patient085/patient085_frame09.nii.gz
#  extracting: data/ACDC/database/training/patient085/patient085_frame09_gt.nii.gz
#  extracting: data/ACDC/database/training/patient086/Info.cfg
#  extracting: data/ACDC/database/training/patient086/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/training/patient086/patient086_4d.nii.gz
#  extracting: data/ACDC/database/training/patient086/patient086_frame01.nii.gz
#  extracting: data/ACDC/database/training/patient086/patient086_frame01_gt.nii.gz
#  extracting: data/ACDC/database/training/patient086/patient086_frame08.nii.gz
#  extracting: data/ACDC/database/training/patient086/patient086_frame08_gt.nii.gz
#  extracting: data/ACDC/database/training/patient087/Info.cfg
#  extracting: data/ACDC/database/training/patient087/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/training/patient087/patient087_4d.nii.gz
#  extracting: data/ACDC/database/training/patient087/patient087_frame01.nii.gz
#  extracting: data/ACDC/database/training/patient087/patient087_frame01_gt.nii.gz
#  extracting: data/ACDC/database/training/patient087/patient087_frame10.nii.gz
#  extracting: data/ACDC/database/training/patient087/patient087_frame10_gt.nii.gz
#  extracting: data/ACDC/database/training/patient088/Info.cfg
#  extracting: data/ACDC/database/training/patient088/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/training/patient088/patient088_4d.nii.gz
#  extracting: data/ACDC/database/training/patient088/patient088_frame01.nii.gz
#  extracting: data/ACDC/database/training/patient088/patient088_frame01_gt.nii.gz
#  extracting: data/ACDC/database/training/patient088/patient088_frame12.nii.gz
#  extracting: data/ACDC/database/training/patient088/patient088_frame12_gt.nii.gz
#  extracting: data/ACDC/database/training/patient089/Info.cfg
#  extracting: data/ACDC/database/training/patient089/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/training/patient089/patient089_4d.nii.gz
#  extracting: data/ACDC/database/training/patient089/patient089_frame01.nii.gz
#  extracting: data/ACDC/database/training/patient089/patient089_frame01_gt.nii.gz
#  extracting: data/ACDC/database/training/patient089/patient089_frame10.nii.gz
#  extracting: data/ACDC/database/training/patient089/patient089_frame10_gt.nii.gz
#  extracting: data/ACDC/database/training/patient090/Info.cfg
#  extracting: data/ACDC/database/training/patient090/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/training/patient090/patient090_4d.nii.gz
#  extracting: data/ACDC/database/training/patient090/patient090_frame04.nii.gz
#  extracting: data/ACDC/database/training/patient090/patient090_frame04_gt.nii.gz
#  extracting: data/ACDC/database/training/patient090/patient090_frame11.nii.gz
#  extracting: data/ACDC/database/training/patient090/patient090_frame11_gt.nii.gz
#  extracting: data/ACDC/database/training/patient091/Info.cfg
#  extracting: data/ACDC/database/training/patient091/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/training/patient091/patient091_4d.nii.gz
#  extracting: data/ACDC/database/training/patient091/patient091_frame01.nii.gz
#  extracting: data/ACDC/database/training/patient091/patient091_frame01_gt.nii.gz
#  extracting: data/ACDC/database/training/patient091/patient091_frame09.nii.gz
#  extracting: data/ACDC/database/training/patient091/patient091_frame09_gt.nii.gz
#  extracting: data/ACDC/database/training/patient092/Info.cfg
#  extracting: data/ACDC/database/training/patient092/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/training/patient092/patient092_4d.nii.gz
#  extracting: data/ACDC/database/training/patient092/patient092_frame01.nii.gz
#  extracting: data/ACDC/database/training/patient092/patient092_frame01_gt.nii.gz
#  extracting: data/ACDC/database/training/patient092/patient092_frame06.nii.gz
#  extracting: data/ACDC/database/training/patient092/patient092_frame06_gt.nii.gz
#  extracting: data/ACDC/database/training/patient093/Info.cfg
#  extracting: data/ACDC/database/training/patient093/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/training/patient093/patient093_4d.nii.gz
#  extracting: data/ACDC/database/training/patient093/patient093_frame01.nii.gz
#  extracting: data/ACDC/database/training/patient093/patient093_frame01_gt.nii.gz
#  extracting: data/ACDC/database/training/patient093/patient093_frame14.nii.gz
#  extracting: data/ACDC/database/training/patient093/patient093_frame14_gt.nii.gz
#  extracting: data/ACDC/database/training/patient094/Info.cfg
#  extracting: data/ACDC/database/training/patient094/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/training/patient094/patient094_4d.nii.gz
#  extracting: data/ACDC/database/training/patient094/patient094_frame01.nii.gz
#  extracting: data/ACDC/database/training/patient094/patient094_frame01_gt.nii.gz
#  extracting: data/ACDC/database/training/patient094/patient094_frame07.nii.gz
#  extracting: data/ACDC/database/training/patient094/patient094_frame07_gt.nii.gz
#  extracting: data/ACDC/database/training/patient095/Info.cfg
#  extracting: data/ACDC/database/training/patient095/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/training/patient095/patient095_4d.nii.gz
#  extracting: data/ACDC/database/training/patient095/patient095_frame01.nii.gz
#  extracting: data/ACDC/database/training/patient095/patient095_frame01_gt.nii.gz
#  extracting: data/ACDC/database/training/patient095/patient095_frame12.nii.gz
#  extracting: data/ACDC/database/training/patient095/patient095_frame12_gt.nii.gz
#  extracting: data/ACDC/database/training/patient096/Info.cfg
#  extracting: data/ACDC/database/training/patient096/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/training/patient096/patient096_4d.nii.gz
#  extracting: data/ACDC/database/training/patient096/patient096_frame01.nii.gz
#  extracting: data/ACDC/database/training/patient096/patient096_frame01_gt.nii.gz
#  extracting: data/ACDC/database/training/patient096/patient096_frame08.nii.gz
#  extracting: data/ACDC/database/training/patient096/patient096_frame08_gt.nii.gz
#  extracting: data/ACDC/database/training/patient097/Info.cfg
#  extracting: data/ACDC/database/training/patient097/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/training/patient097/patient097_4d.nii.gz
#  extracting: data/ACDC/database/training/patient097/patient097_frame01.nii.gz
#  extracting: data/ACDC/database/training/patient097/patient097_frame01_gt.nii.gz
#  extracting: data/ACDC/database/training/patient097/patient097_frame11.nii.gz
#  extracting: data/ACDC/database/training/patient097/patient097_frame11_gt.nii.gz
#  extracting: data/ACDC/database/training/patient098/Info.cfg
#  extracting: data/ACDC/database/training/patient098/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/training/patient098/patient098_4d.nii.gz
#  extracting: data/ACDC/database/training/patient098/patient098_frame01.nii.gz
#  extracting: data/ACDC/database/training/patient098/patient098_frame01_gt.nii.gz
#  extracting: data/ACDC/database/training/patient098/patient098_frame09.nii.gz
#  extracting: data/ACDC/database/training/patient098/patient098_frame09_gt.nii.gz
#  extracting: data/ACDC/database/training/patient099/Info.cfg
#  extracting: data/ACDC/database/training/patient099/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/training/patient099/patient099_4d.nii.gz
#  extracting: data/ACDC/database/training/patient099/patient099_frame01.nii.gz
#  extracting: data/ACDC/database/training/patient099/patient099_frame01_gt.nii.gz
#  extracting: data/ACDC/database/training/patient099/patient099_frame09.nii.gz
#  extracting: data/ACDC/database/training/patient099/patient099_frame09_gt.nii.gz
#  extracting: data/ACDC/database/training/patient100/Info.cfg
#  extracting: data/ACDC/database/training/patient100/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/training/patient100/patient100_4d.nii.gz
#  extracting: data/ACDC/database/training/patient100/patient100_frame01.nii.gz
#  extracting: data/ACDC/database/training/patient100/patient100_frame01_gt.nii.gz
#  extracting: data/ACDC/database/training/patient100/patient100_frame13.nii.gz
#  extracting: data/ACDC/database/training/patient100/patient100_frame13_gt.nii.gz
#  extracting: data/ACDC/database/training/MANDATORY_CITATION.md
#  extracting: data/ACDC/database/MANDATORY_CITATION.md

# %%
DATA_ROOT = 'data'

ACDC = {
    'id': 0,
    'image_size': (192, 192),
    'raw_path': DATA_ROOT + '/ACDC/database/training',
    'training_set': {
        'path': DATA_ROOT + '/ACDC/training',
        'path_normalized': DATA_ROOT + '/ACDC/training_normalized',
        'path_normalized_images': DATA_ROOT + '/ACDC/training_normalized' + '/images',
        'path_normalized_masks': DATA_ROOT + '/ACDC/training_normalized' + '/masks'
    },
    'testing_set': {
        'path': DATA_ROOT + '/ACDC/database/testing',
        'path_normalized': DATA_ROOT + '/ACDC/testing_normalized',
        'path_normalized_images': DATA_ROOT + '/ACDC/testing_normalized' + '/images',
        'path_normalized_masks': DATA_ROOT + '/ACDC/testing_normalized' + '/masks'
    }
}

# %%
import os
import random
import shutil
import numpy as np

# %%
def create_directory(path):
    if os.path.exists(path):
        shutil.rmtree(path)
    os.mkdir(path)

    return None

# %%
os.remove('data/ACDC/database/training/MANDATORY_CITATION.md')

# %%
def split_training_testing_set(config, percentage):
    """
    Split the raw directory in a training and a testing set.
    :param config: json, access path.
    :param percentage: int, percentage of the raw directory given to the training set.
    :return: None
    """
    patients = os.listdir(config['raw_path'])
    print(patients)
    nb_patient = 0
    for _ in patients:
        nb_patient += 1
    testing_set_count = round(nb_patient - ((nb_patient / 100) * percentage))
    testing_set_images = random.sample(os.listdir(config['raw_path']), testing_set_count)
    training_set_images = np.setdiff1d(patients, testing_set_images)

    create_directory(config['testing_set']['path'])
    create_directory(config['training_set']['path'])

    for patient in testing_set_images:
        print(patient)
        shutil.copytree(config['raw_path'] + "/" + patient, config['testing_set']['path'] +"/"+ patient)
    for patient in training_set_images:
        print(patient)
        shutil.copytree(config['raw_path'] + "/" + patient, config['training_set']['path'] + "/" + patient)

    return None

# %%
split_training_testing_set(ACDC, percentage=80)
# Out:
# ['patient073', 'patient071', 'patient008', 'patient015', 'patient023', 'patient010', 'patient013', 'patient028', 'patient049', 'patient036', 'patient047', 'patient080', 'patient006', 'patient086', 'patient031', 'patient037', 'patient026', 'patient075', 'patient076', 'patient087', 'patient089', 'patient038', 'patient048', 'patient064', 'patient055', 'patient039', 'patient060', 'patient017', 'patient016', 'patient051', 'patient034', 'patient005', 'patient079', 'patient093', 'patient082', 'patient077', 'patient097', 'patient018', 'patient040', 'patient072', 'patient011', 'patient029', 'patient059', 'patient058', 'patient066', 'patient024', 'patient027', 'patient003', 'patient100', 'patient014', 'patient084', 'patient062', 'patient095', 'patient056', 'patient004', 'patient081', 'patient092', 'patient061', 'patient091', 'patient019', 'patient001', 'patient063', 'patient068', 'patient043', 'patient044', 'patient054', 'patient032', 'patient021', 'patient098', 'patient012', 'patient088', 'patient085', 'patient065', 'patient009', 'patient002', 'patient070', 'patient050', 'patient042', 'patient022', 'patient041', 'patient046', 'patient078', 'patient083', 'patient007', 'patient033', 'patient030', 'patient074', 'patient020', 'patient025', 'patient035', 'patient096', 'patient090', 'patient045', 'patient099', 'patient069', 'patient094', 'patient067', 'patient052', 'patient057', 'patient053']
# patient012
# patient053
# patient035
# patient068
# patient098
# patient052
# patient091
# patient063
# patient020
# patient041
# patient089
# patient014
# patient082
# patient031
# patient083
# patient039
# patient030
# patient011
# patient042
# patient059
# patient001
# patient002
# patient003
# patient004
# patient005
# patient006
# patient007
# patient008
# patient009
# patient010
# patient013
# patient015
# patient016
# patient017
# patient018
# patient019
# patient021
# patient022
# patient023
# patient024
# patient025
# patient026
# patient027
# patient028
# patient029
# patient032
# patient033
# patient034
# patient036
# patient037
# patient038
# patient040
# patient043
# patient044
# patient045
# patient046
# patient047
# patient048
# patient049
# patient050
# patient051
# patient054
# patient055
# patient056
# patient057
# patient058
# patient060
# patient061
# patient062
# patient064
# patient065
# patient066
# patient067
# patient069
# patient070
# patient071
# patient072
# patient073
# patient074
# patient075
# patient076
# patient077
# patient078
# patient079
# patient080
# patient081
# patient084
# patient085
# patient086
# patient087
# patient088
# patient090
# patient092
# patient093
# patient094
# patient095
# patient096
# patient097
# patient099
# patient100

# %%
# !pip install nibabel
# Out:
# Collecting nibabel
#   Downloading nibabel-5.1.0-py3-none-any.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 1.2 MB/s eta 0:00:01
# Requirement already satisfied: packaging>=17 in /home2/sashank.sridhar/miniconda3/envs/TripletLoss/lib/python3.9/site-packages (from nibabel) (21.3)
# Requirement already satisfied: numpy>=1.19 in /home2/sashank.sridhar/miniconda3/envs/TripletLoss/lib/python3.9/site-packages (from nibabel) (1.21.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home2/sashank.sridhar/miniconda3/envs/TripletLoss/lib/python3.9/site-packages (from packaging>=17->nibabel) (2.4.7)
# Installing collected packages: nibabel
# Successfully installed nibabel-5.1.0

# %%
import os
import nibabel as nib
import cv2
import numpy as np
import shutil

# %%
class NormalizationACDC:
    """
    Normalize ACDC dataset:
    Select frames of end systole and end diastole in short axis view.
    Break down frames into slices.
    Transform slices into NumPy arrays.
    Rescale images (spatial resolution of 1mm*2 / pixel).
    Crop images in a square shape (192 pixels) around the center.
    Apply CLAHE transformation.
    Store images in a new directory.
    """
    def __init__(self, config):
        self.path = config['path']
        self.path_normalized = config['path_normalized']
        self.path_normalized_images = config['path_normalized_images']
        self.path_normalized_masks = config['path_normalized_masks']

    def normalize(self):
        self.create_normalized_directory()
        patients = os.listdir(self.path)
        for patient in patients:
            files = os.listdir(self.path +"/"+ patient)
            for file in files:
                file_path = self.path +"/"+ patient +"/"+ file
                new_name = file[:-7]
                if self.get_file_type(file) == 0:
                    images = self.transform_img_to_numpy_arrays(file_path, 0)
                    pixdim = self.get_spatial_resolution(file_path)
                    images_rescaled = self.rescale(images, pixdim)
                    images_cropped = self.crop(images_rescaled)
                    images_clahe = self.clahe(images_cropped)
                    self.save_numpy_images(images_clahe, new_name, 0)

                elif self.get_file_type(file) == 1:
                    images = self.transform_img_to_numpy_arrays(file_path, 1)
                    pixdim = self.get_spatial_resolution(file_path)
                    images_rescaled = self.rescale(images, pixdim)
                    images_cropped = self.crop(images_rescaled)
                    self.save_numpy_images(images_cropped, new_name, 1)

        self.filter_empty_mask()

        return None

    def filter_empty_mask(self):
        """
        After the normalization process, images who does not contain the RV are dropped.
        :return: None
        """
        masks = os.listdir(self.path_normalized_masks)
        total, droped = len(masks), 0
        for mask in masks:
            data = np.load(self.path_normalized_masks +"/"+ mask)
            min, max = np.min(data), np.max(data)
            if max == 0:
                os.remove(self.path_normalized_masks +"/"+ mask)
                os.remove(self.path_normalized_images +"/"+ mask)
                droped += 1

        return None

    def clahe(self, img_arrays, tile_size=(1, 1)):
        """
        Apply the Contrast Limited Adaptative Histogram Equalization transformation to every slices of a frame.
        :param img_arrays: numpy arrays of slices of a frame
        :param tile_size: size of the tiles
        :return: array containing images with CLAHE transformation.
        """
        images_clahe = []
        clahe = cv2.createCLAHE(tileGridSize=tile_size, clipLimit=2.5)
        for img in img_arrays:
            img_8bit = self.convert_16bit_8bit(img)
            images_clahe.append(clahe.apply(img_8bit))

        return images_clahe

    def convert_16bit_8bit(self, img):
        """
        Convert a 16bit image to a 8bit image.
        :param img: numpy array of the 16 bit image
        :return: numpy image of the 8 bit image
        """
        min_16 = np.min(img)
        max_16 = np.max(img)
        img_8 = np.array(np.rint((255 * (img - min_16)) / float(max_16 - min_16)), dtype=np.uint8)

        return img_8

    def crop(self, img_arrays, crop_size=192):
        """
        Crop the image around center in a square shape.
        :param img_arrays: numpy arrays of slices of a frame
        :param crop_size: int
        :return: array containing newly cropped images for every slices of a frame.
        """
        images_croped = []
        for img in img_arrays:
            height, width = img.shape
            crop_x = (width - crop_size) // 2
            crop_y = (height - crop_size) // 2
            image_croped = img[crop_y:(crop_y + crop_size), crop_x:(crop_x + crop_size)]
            images_croped.append(image_croped)

        return images_croped

    def create_normalized_directory(self):
        if os.path.exists(self.path_normalized):
            shutil.rmtree(self.path_normalized)
        os.mkdir(self.path_normalized)
        os.mkdir(self.path_normalized_images)
        os.mkdir(self.path_normalized_masks)

        return None

    def get_file_type(self, file_name):
        """
        Label the type of file. 4 options possible.
        Type 0 = unlabeled ES and ED frames
        Type 1 = labeled ES and ED frames
        Type 2 = Complete 4D image
        Type 3 = Info file
        :param file_name: str
        :return: int
        """
        if file_name[-9:] == "gt.nii.gz":
            return 1
        elif file_name[-9:] == "4d.nii.gz":
            return 2
        elif file_name == 'Info.cfg' or file_name == 'MANDATORY_CITATION.md':
            return 3
        else:
            return 0

    def filter_right_ventricle(self, img):
        """
        Only select the RV labeled class
        :param img: numpy array of the image
        :return: numpy array of the filtered image
        """
        img[img > 1] = 0

        return img

    def transform_img_to_numpy_arrays(self, file_path, file_type):
        img_obj = nib.load(file_path)
        img_data = img_obj.get_fdata()

        if file_type == 1:
            img_data = self.filter_right_ventricle(img_data)

        depth = img_data.shape[2]
        images = []
        for i in range(depth):
            images.append(np.array(img_data[:, :, i]))

        return images

    def get_spatial_resolution(self, file_path):
        img_obj = nib.load(file_path)
        header_infos = img_obj.header

        return header_infos.get_zooms()

    def rescale(self, images, pixdim):
        """
        Rescale every images in order to obtain a spatial resolution of 1mm^2 / pixel
        :param images: numpy arrays of slices of a frame
        :param pixdim: spatial resolution of the images
        :return: numpy arrays of rescaled images
        """
        images_rescaled = []
        for image in images:
            images_rescaled.append(
                cv2.resize(image, (0, 0), fx=pixdim[0], fy=pixdim[1])
            )

        return images_rescaled

    def save_numpy_images(self, images_normalized, new_name, img_type):
        if img_type == 1:
            path = self.path_normalized_masks
        else:
            path = self.path_normalized_images
        i = 0
        for image in images_normalized:
            if new_name[-3:] == '_gt':
                new_name = new_name[:-3]
            n = new_name + '_' + str(i)
            np.save(path +"/"+ n, image)
            i += 1

        return 0

# %%
norm_training = NormalizationACDC(ACDC['training_set'])
norm_training.normalize()

# %%
norm_testing = NormalizationACDC(ACDC['testing_set'])
norm_testing.normalize()
